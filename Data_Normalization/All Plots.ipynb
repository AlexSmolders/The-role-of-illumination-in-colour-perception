# %% [markdown]
# # Alex Smolders
# ### 100825116

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, Latex
import csv
# Out:
# c:\Users\alexs\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\alexs\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
X = 1
Y = np.linspace(0, 20, 100)
Z = 1


x = X/(X+Y+Z)
y = Y/(X+Y+Z)

plt.plot(Y, x, label = 'x')
plt.plot(Y, y, label = 'y')
plt.legend()

# %%
bvx = np.loadtxt('Vinyl_blue_5.txt', usecols = (0))
bvy = np.loadtxt('Vinyl_blue_5.txt', usecols = (1)) / 100
bsx = np.loadtxt('Shirt_blue_5.txt', usecols = (0))
bsy = np.loadtxt('Shirt_blue_5.txt', usecols = (1)) / 100
plt.figure(figsize = (10,6))
plt.plot(bvx, bvy, label = 'Vinyl')
plt.plot(bsx, bsy, label = 'Shirt')
plt.legend()
plt.xlabel('nm')
plt.ylabel('%R')
plt.title('Blue')
#plt.savefig('Blue.pdf')
plt.show()

c = open("vb_norm.txt", "w")
dat = np.column_stack([bvx, bvy])
np.savetxt(c, dat, fmt=['%10.2f','%10.10f'])

f = open("sb_norm.txt", "w")
data = np.column_stack([bsx, bsy])
np.savetxt(f, data, fmt=['%10.2f','%10.10f'])

# %%
osx = np.loadtxt('Shirt_orange_5.txt', usecols = (0))
osy = np.loadtxt('Shirt_orange_5.txt', usecols = (1)) / 100
plt.figure(figsize = (10,6))
plt.plot(osx, osy, label = 'Shirt')
plt.legend()
plt.xlabel('nm')
plt.ylabel('%R')
plt.title('Orange')
#plt.savefig('Blue.pdf')
plt.show()



f = open("so_norm.txt", "w")
data = np.column_stack([osx, osy])
np.savetxt(f, data, fmt=['%10.2f','%10.10f'])

# %%
rvx = np.loadtxt('Vinyl_red_5.txt', usecols = (0))
rvy = np.loadtxt('Vinyl_red_5.txt', usecols = (1)) /100
rsx = np.loadtxt('Shirt_red_5.txt', usecols = (0))
rsy = np.loadtxt('Shirt_red_5.txt', usecols = (1)) /100
plt.figure(figsize = (10,6))
plt.plot(rvx, rvy, label = 'Vinyl')
plt.plot(rsx, rsy, label = 'Shirt')
plt.legend()
plt.xlabel('nm')
plt.ylabel('%R')
plt.title('Red')
#plt.savefig('Red.pdf')
plt.show()

c = open("vr_norm.txt", "w")
dat = np.column_stack([rvx, rvy])
np.savetxt(c, dat, fmt=['%10.2f','%10.10f'])

f = open("sr_norm.txt", "w")
data = np.column_stack([rsx, rsy])
np.savetxt(f, data, fmt=['%10.2f','%10.10f'])

# %%
gvx = np.loadtxt('Vinyl_green_5.txt', usecols = (0))
gvy = np.loadtxt('Vinyl_green_5.txt', usecols = (1)) / 100
gsx = np.loadtxt('Shirt_green_5.txt', usecols = (0))
gsy = np.loadtxt('Shirt_green_5.txt', usecols = (1)) / 100
plt.figure(figsize = (10,6))
plt.plot(gvx, gvy, label = 'Vinyl')
plt.plot(gsx, gsy, label = 'Shirt')
plt.legend()
plt.xlabel('nm')
plt.ylabel('%R')
plt.title('Green')
#plt.savefig('Green.pdf')
plt.show()

c = open("vg_norm.txt", "w")
dat = np.column_stack([gvx, gvy])
np.savetxt(c, dat, fmt=['%10.2f','%10.10f'])

f = open("sg_norm.txt", "w")
data = np.column_stack([gsx, gsy])
np.savetxt(f, data, fmt=['%10.2f','%10.10f'])

# %%
yvx = np.loadtxt('Vinyl_yellow_5.txt', usecols = (0))
yvy = np.loadtxt('Vinyl_yellow_5.txt', usecols = (1)) / 100
ysx = np.loadtxt('Shirt_yellow_5.txt', usecols = (0))
ysy = np.loadtxt('Shirt_yellow_5.txt', usecols = (1)) / 100
plt.figure(figsize = (10,6))
plt.plot(yvx, yvy, label = 'Vinyl')
plt.plot(ysx, ysy, label = 'Shirt')
plt.legend()
plt.xlabel('nm')
plt.ylabel('%R')
plt.title('Yellow')
#plt.savefig('Yellow.pdf')
plt.show()

c = open("vy_norm.txt", "w")
dat = np.column_stack([yvx, yvy])
np.savetxt(c, dat, fmt=['%10.2f','%10.10f'])

f = open("sy_norm.txt", "w")
data = np.column_stack([ysx, ysy])
np.savetxt(f, data, fmt=['%10.2f','%10.10f'])

# %%
gyvx = np.loadtxt('Vinyl_grey_4.txt', usecols = (0))
gyvy = np.loadtxt('Vinyl_grey_4.txt', usecols = (1)) / 100
gysx = np.loadtxt('Shirt_grey_4.txt', usecols = (0))
gysy = np.loadtxt('Shirt_grey_4.txt', usecols = (1)) / 100
plt.figure(figsize = (10,6))
plt.plot(gyvx, gyvy, label = 'Vinyl')
plt.plot(gysx, gysy, label = 'Shirt')
plt.legend()
plt.xlabel('nm')
plt.ylabel('%R')
plt.title('Grey')
#plt.savefig('Grey.pdf')
plt.show()

# %%
nm5 = np.loadtxt('CRI 80.txt', usecols = (0))
c80 = np.loadtxt('CRI 80.txt', usecols = (1))
c80 = c80/np.max(c80)


nm6 = np.loadtxt('CRI 90.txt', usecols = (0))
c90 = np.loadtxt('CRI 90.txt', usecols = (1))
c90 = c90/np.max(c90)


nm7 = np.loadtxt('CRI 100.txt', usecols = (0))
c100 = np.loadtxt('CRI 100.txt', usecols = (1))
c100 = c100/np.max(c100)


nm2 = np.loadtxt('CRI 45.txt', usecols = (0))
c45 = np.loadtxt('CRI 45.txt', usecols = (1))
c45 = c45/np.max(c45)


nm1 = np.loadtxt('CRI 22.txt', usecols = (0))
c22 = np.loadtxt('CRI 22.txt', usecols = (1))
c22 = c22/np.max(c22)


nm3 = np.loadtxt('CRI 60.txt', usecols = (0))
c60 = np.loadtxt('CRI 60.txt', usecols = (1))
c60 = c60/np.max(c60)

nms = np.loadtxt('CIE_std_illum_D65.txt', usecols = (0))
d65 = np.loadtxt('CIE_std_illum_D65.txt', usecols = (1))
d65 = d65/np.max(d65)

nm4 = np.loadtxt('CRI 70.txt', usecols = (0))
c70 = np.loadtxt('CRI 70.txt', usecols = (1))
c70 = c70/np.max(c70)
plt.figure(figsize = (10,6))

plt.plot(nm1, c22, label = 'CRI 22')
#plt.plot(nm2, c45, label = 'CRI 45')
plt.plot(nm3, c60, label = 'CRI 60')
#plt.plot(nm4, c70, label = 'CRI 70')
#plt.plot(nm5, c80, label = 'CRI 80')
#plt.plot(nm6, c90, label = 'CRI 90')
plt.plot(nm7, c100, label = 'CRI 100')

plt.legend()
plt.xlabel('nm')
plt.ylabel('%E')
plt.show()

# %%
data = np.column_stack([nm1, c22])
np.savetxt("CRI_22_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
data = np.column_stack([nms, d65])
np.savetxt("d65_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
data = np.column_stack([nm2, c45])
np.savetxt("CRI_45_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
data = np.column_stack([nm3, c60])
np.savetxt("CRI_60_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
data = np.column_stack([nm4, c70])
np.savetxt("CRI_70_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
data = np.column_stack([nm5, c80])
np.savetxt("CRI_80_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
data = np.column_stack([nm6, c90])
np.savetxt("CRI_90_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
data = np.column_stack([nm7, c100])
np.savetxt("CRI_100_norm.dat", data, fmt=['%10.2f','%10.10f'])

# %%
plt.figure(figsize = (10,6))
plt.plot(nm, c80, label = 'CRI 80')
plt.plot(gvx, gvy, label = 'Green Vinyl')

plt.legend()
plt.xlabel('nm')
plt.ylabel('%R')
plt.title('Green')
plt.show()

# %%
L22 = 9500
L45 = 2350
L60 = 3200
L80 = 750
L100 = 218

x = np.linspace(0.1, 1, 100)
f22 = L22/(4*np.pi* (x**2))
f45 = L45/(4*np.pi* x**2)
f60 = L60/(4*np.pi* x**2)
f80 = L80/(4*np.pi* x**2)
f100 = L100/(4*np.pi* x**2)
#plt.figure(figsize = (10,6))
#plt.plot(x, f22, label = 'CRI 22')
#plt.plot(x, f45, label = 'CRI 45')
#plt.plot(x, f60, label = 'CRI 60')
#plt.plot(x, f80, label = 'CRI 80')
#plt.plot(x, f100, label = 'CRI 100')

#plt.legend()
#plt.xlabel('Distance')
#plt.ylabel('Flux')
#plt.show()

x100 = 0.25
f100 = L100/(4*np.pi* x100**2)
print(f"For the CRI 100 Buld, at a distance {x100}m, the flux is {f100:.4} L/m^2")

d80 = np.sqrt(L80/(4*np.pi*f100))
print(f"For the CRI 80 Buld, to get a flux of {f100:.4} L/m^2, the bulb needs to be {d80:.4} m")

d60 = np.sqrt(L60/(4*np.pi*f100))
print(f"For the CRI 60 Buld, to get a flux of {f100:.4} L/m^2, the bulb needs to be {d60:.4} m")

d45 = np.sqrt(L45/(4*np.pi*f100))
print(f"For the CRI 45 Buld, to get a flux of {f100:.4} L/m^2, the bulb needs to be {d45:.4} m")

d22 = np.sqrt(L22/(4*np.pi*f100))
print(f"For the CRI 22 Buld, to get a flux of {f100:.4} L/m^2, the bulb needs to be {d22:.4} m")
# Out:
# For the CRI 100 Buld, at a distance 0.25m, the flux is 277.6 L/m^2
# For the CRI 80 Buld, to get a flux of 277.6 L/m^2, the bulb needs to be 0.4637 m
# For the CRI 60 Buld, to get a flux of 277.6 L/m^2, the bulb needs to be 0.9578 m
# For the CRI 45 Buld, to get a flux of 277.6 L/m^2, the bulb needs to be 0.8208 m
# For the CRI 22 Buld, to get a flux of 277.6 L/m^2, the bulb needs to be 1.65 m
